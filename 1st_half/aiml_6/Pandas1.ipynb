# %% [markdown]
# # Pandas 1

# %%
import pandas as pd

# %%
import os

# %%
data=pd.read_csv('weather_city.csv')

# %%
data
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york           32          6    Rain
# 1   01-02-2017  new york           36          7   Sunny
# 2   01-03-2017  new york           28         12    Snow
# 3   01-04-2017  new york           33          7   Sunny
# 4   01-01-2017    mumbai           90          5   Sunny
# 5   01-02-2017    mumbai           85         12     Fog
# 6   01-03-2017    mumbai           87         15     Fog
# 7   01-04-2017    mumbai           92          5    Rain
# 8   01-01-2017     paris           45         20   Sunny
# 9   01-02-2017     paris           50         13  Cloudy
# 10  01-03-2017     paris           54          8  Cloudy
# 11  01-04-2017     paris           42         10  Cloudy

# %%
data[['temperature']]
# Out:
#     temperature
# 0            32
# 1            36
# 2            28
# 3            33
# 4            90
# 5            85
# 6            87
# 7            92
# 8            45
# 9            50
# 10           54
# 11           42

# %%
data.temperature
# Out:
# 0     32
# 1     36
# 2     28
# 3     33
# 4     90
# 5     85
# 6     87
# 7     92
# 8     45
# 9     50
# 10    54
# 11    42
# Name: temperature, dtype: int64

# %%
max_value = data[data['temperature'] == data['temperature'].max()
]

# %%
max_value
# Out:
#           day    city  temperature  windspeed event
# 7  01-04-2017  mumbai           92          5  Rain

# %%
min_value = data[data['temperature'] == data['temperature'].min()]

# %%
min_value
# Out:
#           day      city  temperature  windspeed event
# 2  01-03-2017  new york           28         12  Snow

# %%
day_with_max_temp = data[data['temperature'] == data['temperature'].max()][['day','temperature']]

# %%
day_with_max_temp
# Out:
#           day  temperature
# 7  01-04-2017           92

# %%
data[['day','temperature']][data['temperature'] == data['temperature'].max()]
# Out:
#           day  temperature
# 7  01-04-2017           92

# %%
data.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
data.columns
# Out:
# Index(['day', 'city', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
data1=pd.read_csv('weather_city.csv' ,names=[ 'city', 'temperature', 'windspeed', 'event'])

# %%
data1
# Out:
#                 city  temperature  windspeed   event
# day             city  temperature  windspeed   event
# 01-01-2017  new york           32          6    Rain
# 01-02-2017  new york           36          7   Sunny
# 01-03-2017  new york           28         12    Snow
# 01-04-2017  new york           33          7   Sunny
# 01-01-2017    mumbai           90          5   Sunny
# 01-02-2017    mumbai           85         12     Fog
# 01-03-2017    mumbai           87         15     Fog
# 01-04-2017    mumbai           92          5    Rain
# 01-01-2017     paris           45         20   Sunny
# 01-02-2017     paris           50         13  Cloudy
# 01-03-2017     paris           54          8  Cloudy
# 01-04-2017     paris           42         10  Cloudy

# %%
data1.loc['01-01-2017']
# Out:
#                 city temperature windspeed  event
# 01-01-2017  new york          32         6   Rain
# 01-01-2017    mumbai          90         5  Sunny
# 01-01-2017     paris          45        20  Sunny

# %%
data=data.set_index('day')

# %%
data.set_index('day',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5940\3541406004.py in ?()
# ----> 1 data.set_index('day',inplace=True)
#
# d:\z_Developer\AIML\AI-ML-DataCore\venv\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['day'] are in the columns"

# %%
data.loc['01-03-2017']
# Out:
#                 city  temperature  windspeed   event
# day
# 01-03-2017  new york           28         12    Snow
# 01-03-2017    mumbai           87         15     Fog
# 01-03-2017     paris           54          8  Cloudy

# %%
data.reset_index()
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york           32          6    Rain
# 1   01-02-2017  new york           36          7   Sunny
# 2   01-03-2017  new york           28         12    Snow
# 3   01-04-2017  new york           33          7   Sunny
# 4   01-01-2017    mumbai           90          5   Sunny
# 5   01-02-2017    mumbai           85         12     Fog
# 6   01-03-2017    mumbai           87         15     Fog
# 7   01-04-2017    mumbai           92          5    Rain
# 8   01-01-2017     paris           45         20   Sunny
# 9   01-02-2017     paris           50         13  Cloudy
# 10  01-03-2017     paris           54          8  Cloudy
# 11  01-04-2017     paris           42         10  Cloudy

# %%
data.day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9508\2826546505.py in ?()
# ----> 1 data.day
#
# C:\phython\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'day'

# %%
data.reset_index(inplace=True)

# %%
data.day
# Out:
# 0     01-01-2017
# 1     01-02-2017
# 2     01-03-2017
# 3     01-04-2017
# 4     01-01-2017
# 5     01-02-2017
# 6     01-03-2017
# 7     01-04-2017
# 8     01-01-2017
# 9     01-02-2017
# 10    01-03-2017
# 11    01-04-2017
# Name: day, dtype: object

# %%
data1.reset_index()
# Out:
#          index      city  temperature  windspeed   event
# 0          day      city  temperature  windspeed   event
# 1   01-01-2017  new york           32          6    Rain
# 2   01-02-2017  new york           36          7   Sunny
# 3   01-03-2017  new york           28         12    Snow
# 4   01-04-2017  new york           33          7   Sunny
# 5   01-01-2017    mumbai           90          5   Sunny
# 6   01-02-2017    mumbai           85         12     Fog
# 7   01-03-2017    mumbai           87         15     Fog
# 8   01-04-2017    mumbai           92          5    Rain
# 9   01-01-2017     paris           45         20   Sunny
# 10  01-02-2017     paris           50         13  Cloudy
# 11  01-03-2017     paris           54          8  Cloudy
# 12  01-04-2017     paris           42         10  Cloudy

# %% [markdown]
# # Pandas 2

# %%
import pandas as pd

# %%
data=pd.read_csv('weather_city_deleted.csv')

# %%
data
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0          6    Rain
# 1   01-02-2017  new york         36.0          7   Sunny
# 2   01-03-2017  new york          NaN         12    Snow
# 3   01-04-2017      n.a.          NaN          7     NaN
# 4   01-01-2017    mumbai          NaN          5   Sunny
# 5   01-02-2017    mumbai         85.0       -999     Fog
# 6   01-03-2017    mumbai          NaN         15     Fog
# 7   01-04-2017    mumbai         92.0          5    Rain
# 8   01-01-2017     paris         45.0         20   Sunny
# 9   01-02-2017     paris         50.0         13  Cloudy
# 10  01-03-2017     paris         54.0          8     NaN
# 11  01-04-2017     paris         42.0      -2536  Cloudy

# %%
data=pd.read_csv('weather_city_deleted.csv',na_values=['n.a.'])

# %%
data
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0          6    Rain
# 1   01-02-2017  new york         36.0          7   Sunny
# 2   01-03-2017  new york          NaN         12    Snow
# 3   01-04-2017       NaN          NaN          7     NaN
# 4   01-01-2017    mumbai          NaN          5   Sunny
# 5   01-02-2017    mumbai         85.0       -999     Fog
# 6   01-03-2017    mumbai          NaN         15     Fog
# 7   01-04-2017    mumbai         92.0          5    Rain
# 8   01-01-2017     paris         45.0         20   Sunny
# 9   01-02-2017     paris         50.0         13  Cloudy
# 10  01-03-2017     paris         54.0          8     NaN
# 11  01-04-2017     paris         42.0      -2536  Cloudy

# %%
data=pd.read_csv('weather_city_deleted.csv',na_values=['n.a.','-999'])

# %%
data
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york          NaN       12.0    Snow
# 3   01-04-2017       NaN          NaN        7.0     NaN
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        NaN     Fog
# 6   01-03-2017    mumbai          NaN       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0     NaN
# 11  01-04-2017     paris         42.0    -2536.0  Cloudy

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          12 non-null     object
#  1   city         11 non-null     object
#  2   temperature  8 non-null      float64
#  3   windspeed    11 non-null     float64
#  4   event        10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 612.0+ bytes

# %%
data1=pd.read_csv('weather_city_deleted.csv')

# %%
data1
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0          6    Rain
# 1   01-02-2017  new york         36.0          7   Sunny
# 2   01-03-2017  new york          NaN         12    Snow
# 3   01-04-2017      n.a.          NaN          7     NaN
# 4   01-01-2017    mumbai          NaN          5   Sunny
# 5   01-02-2017    mumbai         85.0       -999     Fog
# 6   01-03-2017    mumbai          NaN         15     Fog
# 7   01-04-2017    mumbai         92.0          5    Rain
# 8   01-01-2017     paris         45.0         20   Sunny
# 9   01-02-2017     paris         50.0         13  Cloudy
# 10  01-03-2017     paris         54.0          8     NaN
# 11  01-04-2017     paris         42.0      -2536  Cloudy

# %%
data1=data1[data1.event=='n.a.']

# %%
data1[data1.city=='n.a.']
# Out:
# Empty DataFrame
# Columns: [day, city, temperature, windspeed, event]
# Index: []

# %%
data1.city='Kolkata'

# %%
data1
# Out:
# Empty DataFrame
# Columns: [day, city, temperature, windspeed, event]
# Index: []

# %%
data=pd.read_csv('weather_city_deleted.csv',na_values={'city':'n.a.','windspeed':[-999,-2536]})

# %%
data
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york          NaN       12.0    Snow
# 3   01-04-2017       NaN          NaN        7.0     NaN
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        NaN     Fog
# 6   01-03-2017    mumbai          NaN       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0     NaN
# 11  01-04-2017     paris         42.0        NaN  Cloudy

# %%
data.fillna(12)
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york         12.0       12.0    Snow
# 3   01-04-2017        12         12.0        7.0      12
# 4   01-01-2017    mumbai         12.0        5.0   Sunny
# 5   01-02-2017    mumbai         85.0       12.0     Fog
# 6   01-03-2017    mumbai         12.0       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0      12
# 11  01-04-2017     paris         42.0       12.0  Cloudy

# %%
data=pd.read_csv('weather_city_deleted.csv',na_values=['n.a.',-999,-2536])

# %%
data
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york          NaN       12.0    Snow
# 3   01-04-2017       NaN          NaN        7.0     NaN
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        NaN     Fog
# 6   01-03-2017    mumbai          NaN       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0     NaN
# 11  01-04-2017     paris         42.0        NaN  Cloudy

# %%
data.fillna(12)
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york         12.0       12.0    Snow
# 3   01-04-2017        12         12.0        7.0      12
# 4   01-01-2017    mumbai         12.0        5.0   Sunny
# 5   01-02-2017    mumbai         85.0       12.0     Fog
# 6   01-03-2017    mumbai         12.0       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0      12
# 11  01-04-2017     paris         42.0       12.0  Cloudy

# %%
data.fillna({'city':'Mahismati','windspeed':0,'event':'Not Record',})
# Out:
#            day       city  temperature  windspeed       event
# 0   01-01-2017   new york         32.0        6.0        Rain
# 1   01-02-2017   new york         36.0        7.0       Sunny
# 2   01-03-2017   new york          NaN       12.0        Snow
# 3   01-04-2017  Mahismati          NaN        7.0  Not Record
# 4   01-01-2017     mumbai          NaN        5.0       Sunny
# 5   01-02-2017     mumbai         85.0        0.0         Fog
# 6   01-03-2017     mumbai          NaN       15.0         Fog
# 7   01-04-2017     mumbai         92.0        5.0        Rain
# 8   01-01-2017      paris         45.0       20.0       Sunny
# 9   01-02-2017      paris         50.0       13.0      Cloudy
# 10  01-03-2017      paris         54.0        8.0  Not Record
# 11  01-04-2017      paris         42.0        0.0      Cloudy

# %%
data.fillna(method='ffill')
# Out:
# C:\Users\SAYAN\AppData\Local\Temp\ipykernel_17728\1844443866.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york         36.0       12.0    Snow
# 3   01-04-2017  new york         36.0        7.0    Snow
# 4   01-01-2017    mumbai         36.0        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        5.0     Fog
# 6   01-03-2017    mumbai         85.0       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0  Cloudy
# ...

# %%
#ffill = forword fill

# %%
data.fillna(method='bfill')
# Out:
# C:\Users\SAYAN\AppData\Local\Temp\ipykernel_17728\1397359497.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york         85.0       12.0    Snow
# 3   01-04-2017    mumbai         85.0        7.0   Sunny
# 4   01-01-2017    mumbai         85.0        5.0   Sunny
# 5   01-02-2017    mumbai         85.0       15.0     Fog
# 6   01-03-2017    mumbai         92.0       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0  Cloudy
# ...

# %%
data.fillna(method='bfill',axis='columns')
# Out:
# C:\Users\SAYAN\AppData\Local\Temp\ipykernel_17728\251783446.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill',axis='columns')
#            day      city temperature windspeed   event
# 0   01-01-2017  new york        32.0       6.0    Rain
# 1   01-02-2017  new york        36.0       7.0   Sunny
# 2   01-03-2017  new york        12.0      12.0    Snow
# 3   01-04-2017       7.0         7.0       7.0     NaN
# 4   01-01-2017    mumbai         5.0       5.0   Sunny
# 5   01-02-2017    mumbai        85.0       Fog     Fog
# 6   01-03-2017    mumbai        15.0      15.0     Fog
# 7   01-04-2017    mumbai        92.0       5.0    Rain
# 8   01-01-2017     paris        45.0      20.0   Sunny
# 9   01-02-2017     paris        50.0      13.0  Cloudy
# 10  01-03-2017     paris        54.0       8.0     NaN
# 11  01-04-2017     paris        42.0    Cloudy  Cloudy

# %%
data.fillna(method='ffill',axis='columns')
# Out:
# C:\Users\SAYAN\AppData\Local\Temp\ipykernel_17728\2230537022.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill',axis='columns')
#            day        city temperature windspeed   event
# 0   01-01-2017    new york        32.0       6.0    Rain
# 1   01-02-2017    new york        36.0       7.0   Sunny
# 2   01-03-2017    new york    new york      12.0    Snow
# 3   01-04-2017  01-04-2017  01-04-2017       7.0     7.0
# 4   01-01-2017      mumbai      mumbai       5.0   Sunny
# 5   01-02-2017      mumbai        85.0      85.0     Fog
# 6   01-03-2017      mumbai      mumbai      15.0     Fog
# 7   01-04-2017      mumbai        92.0       5.0    Rain
# 8   01-01-2017       paris        45.0      20.0   Sunny
# 9   01-02-2017       paris        50.0      13.0  Cloudy
# 10  01-03-2017       paris        54.0       8.0     8.0
# ...

# %%
data.fillna(method='ffill',limit=1)
# Out:
# C:\Users\SAYAN\AppData\Local\Temp\ipykernel_17728\2780927079.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill',limit=1)
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york         36.0       12.0    Snow
# 3   01-04-2017  new york          NaN        7.0    Snow
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        5.0     Fog
# 6   01-03-2017    mumbai         85.0       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0  Cloudy
# ...

# %%
data
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york          NaN       12.0    Snow
# 3   01-04-2017       NaN          NaN        7.0     NaN
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        NaN     Fog
# 6   01-03-2017    mumbai          NaN       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0     NaN
# 11  01-04-2017     paris         42.0        NaN  Cloudy

# %%
data.dropna(thresh=3)
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york          NaN       12.0    Snow
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        NaN     Fog
# 6   01-03-2017    mumbai          NaN       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0     NaN
# 11  01-04-2017     paris         42.0        NaN  Cloudy

# %%
data.dropna(thresh=2)
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york          NaN       12.0    Snow
# 3   01-04-2017       NaN          NaN        7.0     NaN
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        NaN     Fog
# 6   01-03-2017    mumbai          NaN       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0     NaN
# 11  01-04-2017     paris         42.0        NaN  Cloudy

# %%
data.dropna(thresh=5)
# Out:
#           day      city  temperature  windspeed   event
# 0  01-01-2017  new york         32.0        6.0    Rain
# 1  01-02-2017  new york         36.0        7.0   Sunny
# 7  01-04-2017    mumbai         92.0        5.0    Rain
# 8  01-01-2017     paris         45.0       20.0   Sunny
# 9  01-02-2017     paris         50.0       13.0  Cloudy

# %%
data.dropna(how='any')
# Out:
#           day      city  temperature  windspeed   event
# 0  01-01-2017  new york         32.0        6.0    Rain
# 1  01-02-2017  new york         36.0        7.0   Sunny
# 7  01-04-2017    mumbai         92.0        5.0    Rain
# 8  01-01-2017     paris         45.0       20.0   Sunny
# 9  01-02-2017     paris         50.0       13.0  Cloudy

# %%
data.dropna(how='all')
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york          NaN       12.0    Snow
# 3   01-04-2017       NaN          NaN        7.0     NaN
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        NaN     Fog
# 6   01-03-2017    mumbai          NaN       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0     NaN
# 11  01-04-2017     paris         42.0        NaN  Cloudy

# %%
data
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york         32.0        6.0    Rain
# 1   01-02-2017  new york         36.0        7.0   Sunny
# 2   01-03-2017  new york          NaN       12.0    Snow
# 3   01-04-2017       NaN          NaN        7.0     NaN
# 4   01-01-2017    mumbai          NaN        5.0   Sunny
# 5   01-02-2017    mumbai         85.0        NaN     Fog
# 6   01-03-2017    mumbai          NaN       15.0     Fog
# 7   01-04-2017    mumbai         92.0        5.0    Rain
# 8   01-01-2017     paris         45.0       20.0   Sunny
# 9   01-02-2017     paris         50.0       13.0  Cloudy
# 10  01-03-2017     paris         54.0        8.0     NaN
# 11  01-04-2017     paris         42.0        NaN  Cloudy

# %%
data.temperature.replace(32,12)
# Out:
# 0     12.0
# 1     36.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5     85.0
# 6      NaN
# 7     92.0
# 8     45.0
# 9     50.0
# 10    54.0
# 11    42.0
# Name: temperature, dtype: float64

# %%
data.temperature.replace('NaN',12)
# Out:
# 0     32.0
# 1     36.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5     85.0
# 6      NaN
# 7     92.0
# 8     45.0
# 9     50.0
# 10    54.0
# 11    42.0
# Name: temperature, dtype: float64

# %%
data.temperature.replace(NaN,12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 data.temperature.replace(NaN,12)
#
# NameError: name 'NaN' is not defined

# %%
import numpy as np

# %%
data.temperature.replace(np.nan,12)
# Out:
# 0     32.0
# 1     36.0
# 2     12.0
# 3     12.0
# 4     12.0
# 5     85.0
# 6     12.0
# 7     92.0
# 8     45.0
# 9     50.0
# 10    54.0
# 11    42.0
# Name: temperature, dtype: float64
